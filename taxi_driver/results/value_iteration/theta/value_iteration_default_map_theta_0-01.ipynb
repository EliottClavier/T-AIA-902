# %% [markdown]
# Résultats avec theta à 0,01 :
#
# - Le nombre moyen de pas est de 13 pour atteindre l'objectif
# - Le temps "d'entrainement" est de 13.27 secondes

# %%
from pathlib import Path

from common.params import TaxiDriverParams
from common.algorithms import ValueIteration
from common.policies import Max
from common.environments import TaxiDriver
from common.plots import TaxiDriverPlots
import time

# %%
params = TaxiDriverParams(
    n_episodes=10000,
    n_runs=100,
    learning_rate=0.85,
    gamma=0.99,
    epsilon=1.0,
    min_epsilon=0.001,
    manual_decay_rate=0.001,
    random_seed=True,
    seed=123,
    max_n_steps=100,
    theta=0.01,  # Convergence threshold for Value Iteration
    savefig_folder=Path("./static/img/taxi_driver/"),
    savemodel_folder=Path("./static/models/taxi_driver/"),
)

# %%
env = TaxiDriver(params).env
# Out:
# C:\Users\clement.mathe\AppData\Local\pypoetry\Cache\virtualenvs\t-aia-902-jP14eWnw-py3.12\Lib\site-packages\gymnasium\envs\registration.py:694: UserWarning: WARN: Overriding environment Custom-TaxiDriver-v3 already in registry.
#   logger.warn(f"Overriding environment {new_spec.id} already in registry.")
# C:\Users\clement.mathe\AppData\Local\pypoetry\Cache\virtualenvs\t-aia-902-jP14eWnw-py3.12\Lib\site-packages\gymnasium\wrappers\record_video.py:94: UserWarning: WARN: Overwriting existing videos at D:\EpitechProjects\T-AIA-902\T-AIA-902-NAN_1\taxi_driver\results\value_iteration\static\episodes\taxi_driver folder (try specifying a different `video_folder` for the `RecordVideo` wrapper if this is not desired)
#   logger.warn(

# %%
algorithm = ValueIteration(
        env=env,
        params=params,
        policy=Max() 
    )

# %%
start_time = time.time()
algorithm.run()

print(f"Execution time: {time.time() - start_time:.2f} seconds")
# Out:
# Execution time: 13.27 seconds

# %%
TaxiDriverPlots.plot(
    policy=algorithm.computed_policy,
    algorithm=algorithm,
    env=env,
    params=params,
)
# Out:
# Moviepy - Building video D:\EpitechProjects\T-AIA-902\T-AIA-902-NAN_1\taxi_driver\results\value_iteration\static\episodes\taxi_driver\rl-video-episode-0.mp4.
# Moviepy - Writing video D:\EpitechProjects\T-AIA-902\T-AIA-902-NAN_1\taxi_driver\results\value_iteration\static\episodes\taxi_driver\rl-video-episode-0.mp4
# Moviepy - Done !
# Moviepy - video ready D:\EpitechProjects\T-AIA-902\T-AIA-902-NAN_1\taxi_driver\results\value_iteration\static\episodes\taxi_driver\rl-video-episode-0.mp4
# Moviepy - Building video D:\EpitechProjects\T-AIA-902\T-AIA-902-NAN_1\taxi_driver\results\value_iteration\static\episodes\taxi_driver\rl-video-episode-1.mp4.
# Moviepy - Writing video D:\EpitechProjects\T-AIA-902\T-AIA-902-NAN_1\taxi_driver\results\value_iteration\static\episodes\taxi_driver\rl-video-episode-1.mp4
# Moviepy - Done !
# Moviepy - video ready D:\EpitechProjects\T-AIA-902\T-AIA-902-NAN_1\taxi_driver\results\value_iteration\static\episodes\taxi_driver\rl-video-episode-1.mp4
# Moviepy - Building video D:\EpitechProjects\T-AIA-902\T-AIA-902-NAN_1\taxi_driver\results\value_iteration\static\episodes\taxi_driver\rl-video-episode-8.mp4.
# Moviepy - Writing video D:\EpitechProjects\T-AIA-902\T-AIA-902-NAN_1\taxi_driver\results\value_iteration\static\episodes\taxi_driver\rl-video-episode-8.mp4
# Moviepy - Done !
# Moviepy - video ready D:\EpitechProjects\T-AIA-902\T-AIA-902-NAN_1\taxi_driver\results\value_iteration\static\episodes\taxi_driver\rl-video-episode-8.mp4
# Moviepy - Building video D:\EpitechProjects\T-AIA-902\T-AIA-902-NAN_1\taxi_driver\results\value_iteration\static\episodes\taxi_driver\rl-video-episode-27.mp4.
# Moviepy - Writing video D:\EpitechProjects\T-AIA-902\T-AIA-902-NAN_1\taxi_driver\results\value_iteration\static\episodes\taxi_driver\rl-video-episode-27.mp4
# Moviepy - Done !
# Moviepy - video ready D:\EpitechProjects\T-AIA-902\T-AIA-902-NAN_1\taxi_driver\results\value_iteration\static\episodes\taxi_driver\rl-video-episode-27.mp4
# Moviepy - Building video D:\EpitechProjects\T-AIA-902\T-AIA-902-NAN_1\taxi_driver\results\value_iteration\static\episodes\taxi_driver\rl-video-episode-64.mp4.
# Moviepy - Writing video D:\EpitechProjects\T-AIA-902\T-AIA-902-NAN_1\taxi_driver\results\value_iteration\static\episodes\taxi_driver\rl-video-episode-64.mp4
# Moviepy - Done !
# Moviepy - video ready D:\EpitechProjects\T-AIA-902\T-AIA-902-NAN_1\taxi_driver\results\value_iteration\static\episodes\taxi_driver\rl-video-episode-64.mp4
