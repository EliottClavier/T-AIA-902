# %% [markdown]
# Résultats avec 1000 épisodes :
#
# - Le nombre moyen de pas est en moyenne à 93 pendant l'exploration, mais atteint les 10 lors des Wins.
# - On a une récompense qui fluctue beaucoup pendant la période, mais qui tend à se rapprocher de 0.
#
# - Enfin, le modèle commence à apprendre et gagne ces premières parties.
# - On obtient un taux de win rate de 8 %.

# %%
from pathlib import Path

from common.params import TaxiDriverParams
from common.algorithms import SARSA
from common.policies import DecayedEpsilonGreedy
from common.environments import TaxiDriver
from common.plots import TaxiDriverPlots

# %%
params = TaxiDriverParams(
    n_episodes=1000,
    n_runs=100,
    learning_rate=0.85,
    gamma=0.99,
    epsilon=1.0,
    min_epsilon=0.001,
    random_seed=True,
    seed=123,
    max_n_steps=100,
    savefig_folder=Path("./static/img/taxi_driver/"),
    savemodel_folder=Path("./static/models/taxi_driver/"),
)

# %%
env = TaxiDriver(params).env

# %%
algorithm = SARSA(
    env=env,
    params=params,
    policy=DecayedEpsilonGreedy(
        initial_epsilon=params.epsilon,
        min_epsilon=params.min_epsilon,
        n_episodes=params.n_episodes,
        manual_decay_rate=0.001,
    ),
)

# %%
algorithm.run()

# %%
TaxiDriverPlots.plot(
    policy=algorithm.computed_policy,
    algorithm=algorithm,
    env=env,
    params=params,
)
